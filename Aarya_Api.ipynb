# %% [markdown]
# <a href="https://colab.research.google.com/github/iyerary/DbBackup/blob/main/Aarya_Api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask_ngrok
# !pip install EVM

# %%
import json
import os
import cv2
import requests
from flask import Flask, request
from flask_ngrok import run_with_ngrok
import base64
import random
import numpy as np
from tensorflow.python.keras.models import load_model
import pickle
import pandas as pd

KeyFile = pd.read_csv("/content/drive/MyDrive/models/database.csv")

app = Flask(__name__)
run_with_ngrok(app)  # Start ngrok when app is run


@app.route("/", methods=['GET', 'POST'])
def hello():
    def data_csv(key_word,ids):
        product_name = list(KeyFile[KeyFile.ProductID == key_word].ProductName)[0]
        product_category = list(KeyFile[KeyFile.ProductID == key_word].ProductCategory)[0]
        product_description = list(KeyFile[KeyFile.ProductID == key_word].Productdescription)[0]
        size = list(KeyFile[KeyFile.ProductID == key_word].Size)[0]
        related_products = list(KeyFile[KeyFile.ProductID == key_word].RelatedProducts)[0]
        images = list(KeyFile[KeyFile.ProductID == key_word].Images)[0]
        buy_link = list(KeyFile[KeyFile.ProductID == key_word].BuyLink)[0]
        brand = list(KeyFile[KeyFile.ProductID == key_word].Brand)[0]
        movie_name = list(KeyFile[KeyFile.ProductID == key_word].MovieName)[0]

        try:
            base_image = base64.b64encode(requests.get(
                images).content)
        except Exception:
            base_image = None

            pass

        json_res =  {'ProductName': product_name,
                               'ProductCategory': product_category,
                               'Productdescription': product_description,
                               'Size': size,
                               'RelatedProducts': related_products,
                               'Images': base_image,
                               'BuyLink': buy_link,
                               'Brand': brand,
                               'MovieName': movie_name,
                               'displayOrder': ids
                               }
        return json_res

    request_data = request.get_json()

    language = request_data['image']
    opt = int(request_data['id'])

    id = random.randint(0, 10000)

    filename = "ImageNo" + str(id) + ".jpeg"

    with open(filename, 'wb+') as image:
        image.write(base64.b64decode(str(language)))

    if opt == 1:  # Which is for location.

        def category_predict(label_no):
            if label_no == 0:
                return "ilha do campche"
            elif label_no == 1:
                return "CSSD_ROVINJ"
            elif label_no == 2:
                return "Kruger national park"
            elif label_no == 3:
                return "amalfi coast"
            elif label_no == 4:
                return "angkor wat, cambodia"
            elif label_no == 5:
                return "bali swing ubud bali"
            elif label_no == 6:
                return "cambuagahay falls phillipines"
            elif label_no == 7:
                return "cannoying empire falls blue mountains australia"
            elif label_no == 8:
                return "cappadocia"
            elif label_no == 9:
                return "cherry blossom japan"
            elif label_no == 10:
                return "cijevna motenegro"
            elif label_no == 11:
                return "geiranger fjord norway"
            elif label_no == 12:
                return "grand canyon"
            elif label_no == 13:
                return "green village bali"
            elif label_no == 14:
                return "huacachina ica peru"
            elif label_no == 15:
                return "java iceland"
            elif label_no == 16:
                return "infinity pool singapore"
            elif label_no == 17:
                return "jesus statue rio de janeiro"
            elif label_no == 18:
                return "Kanhura maldives"
            elif label_no == 19:
                return "kon ha lagoon thailand"
            elif label_no == 20:
                return "kravice montenegro"
            elif label_no == 21:
                return "lake of bled slovenia"
            elif label_no == 22:
                return "lake tahoe nevada"
            elif label_no == 23:
                return "lauter brunnen"
            elif label_no == 24:
                return "machu pichu"
            elif label_no == 25:
                return "matadeiro beach"
            elif label_no == 26:
                return "mont_saint_michel_normandy_france"
            elif label_no == 27:
                return "multnomah_falls,oregon,united_states"
            elif label_no == 28:
                return "mykonos greece"
            elif label_no == 29:
                return "Nathula pass sikkim india"
            elif label_no == 30:
                return "nusa penida bali"
            elif label_no == 31:
                return "pangong lake ladhakh"
            elif label_no == 32:
                return "paro bhutan"
            elif label_no == 33:
                return "plansee tirol austria"
            elif label_no == 34:
                return "ribeirao da ilha brasil"
            elif label_no == 35:
                return "stairway to heaven hawaii"
            elif label_no == 36:
                return "stryn norway"
            elif label_no == 37:
                return "the edge bali"
            elif label_no == 38:
                return "Tracy arm fjord alaska"
            elif label_no == 39:
                return "tromso norway"
            elif label_no == 40:
                return "tosmgo lake sikkim"
            elif label_no == 41:
                return "Tulip garden netherland"
            elif label_no == 42:
                return "Underwater resort maldives"
            elif label_no == 43:
                return "voss norway"

        def label_predict(label_no):
            if label_no == "1_iladecampche":
                return 0
            elif label_no == "CSSD_ROVINJ":
                return 1
            elif label_no == "Kruger_national_park":
                return 2
            elif label_no == "amalfi_coast":
                return 3
            elif label_no == "angkor_wat_combodia":
                return 4
            elif label_no == "bali_swing_ubud_bali":
                return 5
            elif label_no == "cambugahay_falls_siquijor_philippines":
                return 6
            elif label_no == "canonying_empire_falls_blue_mountains_australia":
                return 7
            elif label_no == "cappadocia":
                return 8
            elif label_no == "cherry_blossom_japan":
                return 9
            elif label_no == "cijevna_montenegro":
                return 10
            elif label_no == "geiranger_fjord_norway":
                return 11
            elif label_no == "grand_canyon":
                return 12
            elif label_no == "green_village_bali":
                return 13
            elif label_no == "huacachina_ica_peru":
                return 14
            elif label_no == "ijencraterjavaisland":
                return 15
            elif label_no == "infinity_pool_singapore":
                return 16
            elif label_no == "jesus_statue,_rio_de_janeiro":
                return 17
            elif label_no == "kanuhura_maldives":
                return 18
            elif label_no == "koh_ha_lagoon_,_thailand":
                return 19
            elif label_no == "kravice_montenegro":
                return 20
            elif label_no == "lake_of_bled,_slovenia":
                return 21
            elif label_no == "lake_tahoe_nevada":
                return 22
            elif label_no == "lauterbrunnen":
                return 23
            elif label_no == "machu_pichu":
                return 24
            elif label_no == "matadeiro_beach":
                return 25
            elif label_no == "mont_saint_michel_normandy_france":
                return 26
            elif label_no == "multnomah_falls,oregon,united_states":
                return 27
            elif label_no == "mykonos_greece":
                return 28
            elif label_no == "nathula_pass_sikkim_india":
                return 29
            elif label_no == "nusa_penida_bali":
                return 30
            elif label_no == "pangong_lake_ladhakh":
                return 31
            elif label_no == "paro_bhutan":
                return 32
            elif label_no == "plansee_tirol_austria":
                return 33
            elif label_no == "ribeirao_da_ilha_brasil":
                return 34
            elif label_no == "stariway_to_heaven_hike,oahu,hawaii":
                return 35
            elif label_no == "stryn,norway":
                return 36
            elif label_no == "the_edge_bali":
                return 37
            elif label_no == "tracy_arm_fjord,alaska":
                return 38
            elif label_no == "tromso,_norway":
                return 39
            elif label_no == "tsomgo_lake_sikkim_india":
                return 40
            elif label_no == "tulip_garden_netherlands":
                return 41
            elif label_no == "underwater_resorts_maldives":
                return 42
            elif label_no == "voss_norway":
                return 43

        def model_predict(img_path):
            img = cv2.resize(cv2.imread(img_path), (224, 224))

            # Preprocessing the image
            img = img.reshape(1, 224, 224, 3)
            imd = np.array(img)

            model = load_model('/content/drive/MyDrive/models/Location_identification_model.h5')
            preds = model.predict(imd)

            label_no = np.argmax(preds)
            out = category_predict(label_no)
            return out

        # Input image path
        location_name = model_predict(filename)
        print(location_name)
        main_data = data_csv(location_name,"1")
        final_data = {"products":[main_data]}

        sdf = final_data["products"]
        sdf = str(sdf[0]['RelatedProducts'])
        sdf = sdf.split("\n")

        j = len(sdf)

        final_one = '{"similarProducts":[]}'

        for i in sdf:
            # for j in sef:

            some_data = data_csv(i, j)
            j = j - 1
            final_one = final_one.replace("'", '"')
            gtyhy = json.loads(final_one)
            gtyhy['similarProducts'].append(some_data)
            final_one = json.dumps(gtyhy)


        # print(final_one)
        final_data = str(final_data).replace("'", '"')
        final_one = final_one.replace("'", '"')

        dictA = json.loads(final_data)
        dictB = json.loads(final_one, strict=False)

        dictA.update(dictB)
        jsonStringA = json.dumps(dictA)


        os.remove(filename)

        return jsonStringA

    elif opt == 2:  # Which is for location.
        network = load_model('/content/drive/MyDrive/models/Shoe.h5')
        # Loads EVM model Pickle file
        with open('/content/drive/MyDrive/models/Shoe_EVM_model_vgg16_fulltrain_90acc.pkl', 'rb') as t:
            evm = pickle.load(t)
        # Loads EVM class names
        with open('/content/drive/MyDrive/models/Shoe_class_names_vgg16_fulltrain_90acc.pkl', 'rb') as _c:
            cls = pickle.load(_c)

        _image = cv2.imread(filename)
        _image = cv2.cvtColor(_image, cv2.COLOR_BGR2RGB)
        image = cv2.resize(_image, (160, 160), interpolation=cv2.INTER_AREA)
        image = image / 255
        image = np.expand_dims(image, axis=0)
        out = network.predict(image)

        probbs = []
        for val in evm.probabilities(out)[0]:
            probbs.append(np.max(val))
        lst = np.argsort(np.argsort(probbs))
        first_prob = np.where(lst == 30)
        sec_prob = np.where(lst == 29)
        thrd_prob = np.where(lst == 28)

        reco1 = cls[first_prob[0][0]]
        reco2 = cls[sec_prob[0][0]]
        reco3 = cls[thrd_prob[0][0]]

        if '_cleaned' in reco1:
            reco1 = reco1.strip('_cleaned')
        if '_cleaned' in reco2:
            reco2 = reco2.strip('_cleaned')
        if '_cleaned' in reco3:
            reco3 = reco3.strip('_cleaned')

        # _json_obj = {'Recommendation 1': reco1,
        #              'Recommendation 2': reco2,
        #              'Recommendation 3': reco3}
        main_data = str(data_csv(reco1,"1"))
        main_data = main_data.replace("'", '"')
        main_data1 = data_csv(reco2,"2")
        main_data2 = data_csv(reco3,"3")

        final_data = json.loads(main_data)
        final_data.update(main_data1)
        final_data.update(main_data2)

        fialist = json.dumps(final_data)

        final_data = {"products": [fialist]}

        sdf = final_data["products"]
        sdf = str(sdf[0]['RelatedProducts'])
        sdf = sdf.split("\n")

        j = len(sdf)

        final_one = '{"similarProducts":[]}'

        for i in sdf:
            # for j in sef:

            some_data = data_csv(i, j)
            j = j - 1
            final_one = final_one.replace("'", '"')
            gtyhy = json.loads(final_one)
            gtyhy['similarProducts'].append(some_data)
            final_one = json.dumps(gtyhy)

        # print(final_one)
        final_data = str(final_data).replace("'", '"')
        final_one = final_one.replace("'", '"')

        dictA = json.loads(final_data)
        dictB = json.loads(final_one, strict=False)

        dictA.update(dictB)
        jsonStringB = json.dumps(dictA)


        os.remove(filename)

        return jsonStringB


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://08dbbd4187d2.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# matadeiro beach
# [2021-03-31 14:25:14,783] ERROR in app: Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.7/dist-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
# ...
